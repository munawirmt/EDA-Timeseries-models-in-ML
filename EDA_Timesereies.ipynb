# %% [markdown]
# <a href="https://colab.research.google.com/github/munawirmt/EDA-Timeseries-with-tesla-dataset/blob/main/EDA_Timesereies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TIME SERIES DATA ANALYZE**

# %%
## install pandas-datareader
# !pip install pandas-datareader

# %%
## import libreries
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime
import yfinance as yf

# %%
## load dataset
df_tesla=yf.download('TSLA',start='2023-01-01',end='2026-09-30')
# Out:
# /tmp/ipykernel_1335/2085371794.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_tesla=yf.download('TSLA',start='2023-01-01',end='2026-09-30')
# [*********************100%***********************]  1 of 1 completed

# %%
df_tesla.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2026-09-14  358.970001  367.730011  357.040009  359.779999  32477200
# 2026-09-15  356.579987  362.390015  354.049988  358.750000  30317700
# 2026-09-16  358.079987  365.100006  354.890015  357.929993  32177400
# 2026-09-17  366.200012  374.119995  363.220001  367.480011  38924100
# 2026-09-18  364.269989  370.899994  360.750000  369.000000  51819200

# %%
df_tesla.head()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2023-01-03  108.099998  118.800003  104.639999  118.470001  231402800
# 2023-01-04  113.639999  114.589996  107.519997  109.110001  180389000
# 2023-01-05  110.339996  111.750000  107.160004  110.510002  157986300
# 2023-01-06  113.059998  114.389999  101.809998  103.000000  220911100
# 2023-01-09  119.769997  123.519997  117.110001  118.959999  190284000

# %%
df_tesla['High'].plot(figsize=(12,14))
# Out:
# <Axes: xlabel='Date'>

# %%
## x limit and y limit ,coloring
df_tesla['High'].plot(xlim=['2025-01-01','2026-09-30'],ylim=[0,900],figsize=(12,14),c='green')
# Out:
# <Axes: xlabel='Date'>

# %%
 df_tesla['High'].plot(xlim=['2025-01-01','2026-09-30'],ylim=[0,900],figsize=(12,14),ls='--',c='green')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-17',
#                ...
#                '2026-09-04', '2026-09-08', '2026-09-09', '2026-09-10',
#                '2026-09-11', '2026-09-14', '2026-09-15', '2026-09-16',
#                '2026-09-17', '2026-09-18'],
#               dtype='datetime64[ns]', name='Date', length=931, freq=None)

# %%
index=df_tesla.loc['2025-01-01':'2026-09-30'].index

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 931 entries, 2023-01-03 to 2026-09-18
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, TSLA)   931 non-null    float64
#  1   (High, TSLA)    931 non-null    float64
#  2   (Low, TSLA)     931 non-null    float64
#  3   (Open, TSLA)    931 non-null    float64
#  4   (Volume, TSLA)  931 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 75.9 KB

# %%
share_open=df_tesla.loc['2025-01-01':'2026-09-30']['Open']
share_open
# Out:
# Ticker            TSLA
# Date
# 2025-01-02  390.100006
# 2025-01-03  381.480011
# 2025-01-06  423.200012
# 2025-01-07  405.829987
# 2025-01-08  392.950012
# ...                ...
# 2026-09-14  359.779999
# 2026-09-15  358.750000
# 2026-09-16  357.929993
# 2026-09-17  367.480011
# 2026-09-18  369.000000
#
# [429 rows x 1 columns]

# %%
index
# Out:
# DatetimeIndex(['2025-01-02', '2025-01-03', '2025-01-06', '2025-01-07',
#                '2025-01-08', '2025-01-10', '2025-01-13', '2025-01-14',
#                '2025-01-15', '2025-01-16',
#                ...
#                '2026-09-04', '2026-09-08', '2026-09-09', '2026-09-10',
#                '2026-09-11', '2026-09-14', '2026-09-15', '2026-09-16',
#                '2026-09-17', '2026-09-18'],
#               dtype='datetime64[ns]', name='Date', length=429, freq=None)

# %%
## visualing
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()  ## prevent overlapping
axis.plot(index,share_open)

# %%
## Datetime index
df_tesla=df_tesla.reset_index()
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 931 entries, 0 to 930
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (index, )       931 non-null    int64
#  1   (Date, )        931 non-null    datetime64[ns]
#  2   (Close, TSLA)   931 non-null    float64
#  3   (High, TSLA)    931 non-null    float64
#  4   (Low, TSLA)     931 non-null    float64
#  5   (Open, TSLA)    931 non-null    float64
#  6   (Volume, TSLA)  931 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(2)
# memory usage: 51.0 KB

# %%
df_tesla.set_index('Date',drop=True)
# Out:
# Price      index       Close        High         Low        Open     Volume
# Ticker                  TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2023-01-03     0  108.099998  118.800003  104.639999  118.470001  231402800
# 2023-01-04     1  113.639999  114.589996  107.519997  109.110001  180389000
# 2023-01-05     2  110.339996  111.750000  107.160004  110.510002  157986300
# 2023-01-06     3  113.059998  114.389999  101.809998  103.000000  220911100
# 2023-01-09     4  119.769997  123.519997  117.110001  118.959999  190284000
# ...          ...         ...         ...         ...         ...        ...
# 2026-09-14   926  358.970001  367.730011  357.040009  359.779999   32477200
# 2026-09-15   927  356.579987  362.390015  354.049988  358.750000   30317700
# 2026-09-16   928  358.079987  365.100006  354.890015  357.929993   32177400
# 2026-09-17   929  366.200012  374.119995  363.220001  367.480011   38924100
# ...

# %%
df_tesla.head()
# Out:
# Price  index       Date       Close        High         Low        Open  \
# Ticker                         TSLA        TSLA        TSLA        TSLA
# 0          0 2023-01-03  108.099998  118.800003  104.639999  118.470001
# 1          1 2023-01-04  113.639999  114.589996  107.519997  109.110001
# 2          2 2023-01-05  110.339996  111.750000  107.160004  110.510002
# 3          3 2023-01-06  113.059998  114.389999  101.809998  103.000000
# 4          4 2023-01-09  119.769997  123.519997  117.110001  118.959999
#
# Price      Volume
# Ticker       TSLA
# 0       231402800
# 1       180389000
# 2       157986300
# 3       220911100
# 4       190284000

# %%
## datetime
date=datetime(2026,5,28)
date
# Out:
# datetime.datetime(2026, 5, 28, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 9, 19, 3, 40, 28, 534982)

# %%
date.date()
# Out:
# datetime.date(2026, 5, 28)

# %%
date.day
# Out:
# 28

# %%
date.weekday()
# Out:
# 3

# %%
date.year
# Out:
# 2026

# %%
date.month
# Out:
# 5

# %%
##Time sampling
df_tesla.head()
# Out:
# Price  index       Date       Close        High         Low        Open  \
# Ticker                         TSLA        TSLA        TSLA        TSLA
# 0          0 2023-01-03  108.099998  118.800003  104.639999  118.470001
# 1          1 2023-01-04  113.639999  114.589996  107.519997  109.110001
# 2          2 2023-01-05  110.339996  111.750000  107.160004  110.510002
# 3          3 2023-01-06  113.059998  114.389999  101.809998  103.000000
# 4          4 2023-01-09  119.769997  123.519997  117.110001  118.959999
#
# Price      Volume
# Ticker       TSLA
# 0       231402800
# 1       180389000
# 2       157986300
# 3       220911100
# 4       190284000

# %%
df_tesla.set_index('Date', inplace=True)
df_tesla.resample('A').mean()
# Out:
# /tmp/ipykernel_1335/4016616085.py:2: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample('A').mean()
# Price       index       Close        High         Low        Open  \
# Ticker                   TSLA        TSLA        TSLA        TSLA
# Date
# 2023-12-31  124.5  217.475240  221.631680  212.674320  217.075040
# 2024-12-31  375.5  230.614961  235.587103  225.492976  230.580715
# 2025-12-31  626.5  356.970760  364.804679  348.770040  357.051920
# 2026-12-31  841.0  389.619441  396.606760  382.756760  389.568044
#
# Price             Volume
# Ticker              TSLA
# Date
# 2023-12-31  1.373516e+08
# 2024-12-31  9.483947e+07
# 2025-12-31  9.769656e+07
# 2026-12-31  5.262187e+07

# %%
df_tesla.resample('A').min()
# Out:
# /tmp/ipykernel_1335/4275136183.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample('A').min()
# Price      index       Close        High         Low        Open    Volume
# Ticker                  TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2023-12-31     0  108.099998  111.750000  101.809998  103.000000  65125200
# 2024-12-31   250  142.050003  144.440002  138.800003  140.559998  37167600
# 2025-12-31   502  221.860001  230.100006  214.250000  223.779999  36252900
# 2026-12-31   752  298.320007  309.059998  297.380005  302.700012  23345200

# %%
df_tesla.resample('A').max()
# Out:
# /tmp/ipykernel_1335/1267908331.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample('A').max()
# Price      index       Close        High         Low        Open     Volume
# Ticker                  TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2023-12-31   249  293.339996  299.290009  289.519989  296.040009  306590600
# 2024-12-31   501  479.859985  488.540009  457.510010  475.899994  243869700
# 2025-12-31   751  489.880005  498.829987  485.329987  489.880005  287499800
# 2026-12-31   930  451.670013  458.339996  444.570007  457.799988  115606400

# %%
df_tesla.resample('A').max()['Open'].plot(kind='bar')
# Out:
# /tmp/ipykernel_1335/2205209845.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample('A').max()['Open'].plot(kind='bar')
# <Axes: xlabel='Date'>

# %%
## quarterly start frequency
df_tesla.resample('BA').max()
# Out:
# /tmp/ipykernel_1335/4180362197.py:2: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   df_tesla.resample('BA').max()
# Price      index       Close        High         Low        Open     Volume
# Ticker                  TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2023-12-29   249  293.339996  299.290009  289.519989  296.040009  306590600
# 2024-12-31   501  479.859985  488.540009  457.510010  475.899994  243869700
# 2025-12-31   751  489.880005  498.829987  485.329987  489.880005  287499800
# 2026-12-31   930  451.670013  458.339996  444.570007  457.799988  115606400

# %%
df_tesla.resample('BQS').mean()
# Out:
# Price       index       Close        High         Low        Open  \
# Ticker                   TSLA        TSLA        TSLA        TSLA
# Date
# 2023-01-02   30.5  174.446290  178.257419  169.024193  173.314355
# 2023-04-03   92.5  199.961773  203.469839  195.479515  199.148388
# 2023-07-03  155.0  256.875079  261.710159  252.284445  257.227778
# 2023-10-02  218.0  237.656825  242.112540  232.943332  237.630476
# 2024-01-01  280.0  195.374755  199.072786  191.909508  195.759345
# 2024-04-01  342.0  174.769365  178.120635  171.382697  174.611270
# 2024-07-01  405.5  228.048594  233.345000  222.624531  227.597501
# 2024-10-01  469.5  321.742657  329.200468  313.635469  321.847969
# 2025-01-01  531.5  333.263333  342.694001  324.794335  335.144167
# 2025-04-01  592.5  301.275807  309.282095  292.521774  300.405161
# 2025-07-01  655.5  346.836406  352.236562  340.096720  345.854686
# 2025-10-01  719.5  443.285313  451.889061  434.411092  443.664220
# ...

# %%
## PLOTTING
df_tesla['Open'].resample('M').max().plot(kind='bar',figsize=(15,6))
# Out:
# /tmp/ipykernel_1335/2284912347.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_tesla['Open'].resample('M').max().plot(kind='bar',figsize=(15,6))
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].rolling(11).max().head(20)  ## rolling
# Out:
# Ticker            TSLA
# Date
# 2023-01-03         NaN
# 2023-01-04         NaN
# 2023-01-05         NaN
# 2023-01-06         NaN
# 2023-01-09         NaN
# 2023-01-10         NaN
# 2023-01-11         NaN
# 2023-01-12         NaN
# 2023-01-13         NaN
# 2023-01-17         NaN
# 2023-01-18  136.679993
# 2023-01-19  136.679993
# 2023-01-20  136.679993
# 2023-01-23  145.380005
# 2023-01-24  146.500000
# 2023-01-25  146.500000
# 2023-01-26  161.419998
# 2023-01-27  180.679993
# 2023-01-30  180.679993
# 2023-01-31  180.679993

# %%
df_tesla['Open : 30 days rolling']=df_tesla['Open'].rolling(30).mean()
df_tesla.head(31)
# Out:
# Price      index       Close        High         Low        Open     Volume  \
# Ticker                  TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2023-01-03     0  108.099998  118.800003  104.639999  118.470001  231402800
# 2023-01-04     1  113.639999  114.589996  107.519997  109.110001  180389000
# 2023-01-05     2  110.339996  111.750000  107.160004  110.510002  157986300
# 2023-01-06     3  113.059998  114.389999  101.809998  103.000000  220911100
# 2023-01-09     4  119.769997  123.519997  117.110001  118.959999  190284000
# 2023-01-10     5  118.849998  122.760002  114.919998  121.070000  167642500
# 2023-01-11     6  123.220001  125.949997  120.510002  122.089996  183810800
# 2023-01-12     7  123.559998  124.129997  117.000000  122.559998  169400900
# 2023-01-13     8  122.400002  122.629997  115.599998  116.550003  180714100
# 2023-01-17     9  131.490005  131.699997  125.019997  125.699997  186477000
# ...

# %%
df_tesla[['Open','Open : 30 days rolling']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>
